# %% [markdown]
# <a href="https://colab.research.google.com/github/SushanthKumble/DATASCIENCE/blob/main/25_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **READING DISPAYING AND WRITING THE TEXT FILES**

# %%
import pandas as pd
import numpy as np
cardetail=pd.read_csv("/content/drive/MyDrive/cars.txt")
cardetail
# Out:
#                  mpg        cyl   disp         hp         drat          wt       qsec        vs   am   gear   carb
# 0                                               Mazda
# 1   RX4                 21         6      160     ...
# 2                                               Mazda
# 3   RX4 Wag          21            6      160     ...
# 4   Datsun 710      22.8           4      108     ...
# 5                                            Hornet 4
# 6   Drive           21.4           6      258     ...
# 7                                              Hornet
# 8   Sportabout      18.7           8    360       ...
# 9   Valiant         18.1           6    225       ...
# 10  Duster 360      14.3           8    360       ...
# 11  Merc 240D       24.4           4   146.7      ...
# 12  Merc 230        22.8           4   140.8      ...
# 13  Merc 280        19.2           6   167.6      ...
# 14  Merc 280C       17.8           6   167.6      ...
# ...

# %%
import pandas as pd

# Assuming you already have the cardetail DataFrame
cardetail = pd.read_csv("/content/drive/MyDrive/cars.txt")

# Write DataFrame to a text file
cardetail.to_csv("/content/drive/MyDrive/new_cars.csv", index=False, sep='\t')

print("Data written to text file.")
# Out:
# Data written to text file.

# %% [markdown]
# **READING DISPLAYING AND WRITING THE JSON FILES**

# %%
import pandas as pd
import numpy as np
bankdetail=pd.read_json("/content/drive/MyDrive/bank.json")
bankdetail
# Out:
#     _id,age,sex,region,income,married,children,car,save_act,current_act,mortgage,pep
# 0      ID12101,48,,INNER_CITY,17546.0,,1,,NO,NO,NO,YES
# 1    ID12102,40,MALE,TOWN,30085.1,YES,3,,NO,YES,YES,NO
# 2     ID12103,51,FEMALE,INNER_CITY,,,0,YES,YES,YES,,NO
# 3       ID12104,23,,TOWN,20375.4,YES,3,NO,NO,YES,NO,NO
# 4          ID12105,57,FEMALE,RURAL,,,0,NO,YES,NO,NO,NO
# ..                                                 ...
# 595  ID12696,61,FEMALE,INNER_CITY,47025.0,,2,YES,,,...
# 596  ID12697,30,FEMALE,INNER_CITY,9672.25,YES,0,YES...
# 597  ID12698,,FEMALE,TOWN,15976.3,YES,0,YES,,NO,NO,YES
# 598  ID12699,29,MALE,INNER_CITY,14711.8,YES,0,,YES,...
# 599         ID12700,,,,26671.6,NO,0,YES,NO,YES,YES,YES
#
# [600 rows x 1 columns]

# %%
import pandas as pd

# Assuming you already have the cardetail DataFrame
bankdetail = pd.read_json("/content/drive/MyDrive/bank.json")

# Write DataFrame to a text file
bankdetail.to_json("/content/drive/MyDrive/new_banks.json", orient="records")

print("Data written to text file.")
# Out:
# Data written to text file.

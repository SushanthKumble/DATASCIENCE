# %% [markdown]
# <a href="https://colab.research.google.com/github/SushanthKumble/DATASCIENCE/blob/main/car2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
car=pd.read_csv("/content/drive/MyDrive/DATA SCIENCE LAB/cars.csv")
df=pd.DataFrame(car)
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
car.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
car.tail()
# Out:
#         Unnamed: 0   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
car.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
import matplotlib.pyplot as plt
car.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'mpg'}>, <Axes: title={'center': 'cyl'}>,
#         <Axes: title={'center': 'disp'}>],
#        [<Axes: title={'center': 'hp'}>, <Axes: title={'center': 'drat'}>,
#         <Axes: title={'center': 'wt'}>],
#        [<Axes: title={'center': 'qsec'}>, <Axes: title={'center': 'vs'}>,
#         <Axes: title={'center': 'am'}>],
#        [<Axes: title={'center': 'gear'}>,
#         <Axes: title={'center': 'carb'}>, <Axes: >]], dtype=object)

# %%
car=car.drop(["gear","vs"],axis=1)

# %%
car
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  am  carb
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   1     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   1     4
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   0     1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     2
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   0     1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     4
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   0     2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   0     2
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   0     4
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   0     4
# ...

# %%
car=car.rename(columns={"cyl":"cycle","hp":"horsepower"})
car
# Out:
#              Unnamed: 0   mpg  cycle   disp  horsepower  drat     wt   qsec  \
# 0             Mazda RX4  21.0      6  160.0         110  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0      6  160.0         110  3.90  2.875  17.02
# 2            Datsun 710  22.8      4  108.0          93  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4      6  258.0         110  3.08  3.215  19.44
# 4     Hornet Sportabout  18.7      8  360.0         175  3.15  3.440  17.02
# 5               Valiant  18.1      6  225.0         105  2.76  3.460  20.22
# 6            Duster 360  14.3      8  360.0         245  3.21  3.570  15.84
# 7             Merc 240D  24.4      4  146.7          62  3.69  3.190  20.00
# 8              Merc 230  22.8      4  140.8          95  3.92  3.150  22.90
# 9              Merc 280  19.2      6  167.6         123  3.92  3.440  18.30
# 10            Merc 280C  17.8      6  167.6         123  3.92  3.440  18.90
# ...

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb]
# Index: []

# %%
print(df.drop_duplicates())
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
car.dropna()
# Out:
#              Unnamed: 0   mpg  cycle   disp  horsepower  drat     wt   qsec  \
# 0             Mazda RX4  21.0      6  160.0         110  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0      6  160.0         110  3.90  2.875  17.02
# 2            Datsun 710  22.8      4  108.0          93  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4      6  258.0         110  3.08  3.215  19.44
# 4     Hornet Sportabout  18.7      8  360.0         175  3.15  3.440  17.02
# 5               Valiant  18.1      6  225.0         105  2.76  3.460  20.22
# 6            Duster 360  14.3      8  360.0         245  3.21  3.570  15.84
# 7             Merc 240D  24.4      4  146.7          62  3.69  3.190  20.00
# 8              Merc 230  22.8      4  140.8          95  3.92  3.150  22.90
# 9              Merc 280  19.2      6  167.6         123  3.92  3.440  18.30
# 10            Merc 280C  17.8      6  167.6         123  3.92  3.440  18.90
# ...

# %%
car['Unnamed: 0'].value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("Number of cars by Make")
plt.ylabel('Nuber of cars')
plt.xlabel('Make')
plt.Text(0.5, 0, 'Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
import seaborn as sns
c=car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-70-a7a231adfe0a>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=car.corr()
#                  mpg     cycle      disp  horsepower      drat        wt  \
# mpg         1.000000 -0.852162 -0.847551   -0.776168  0.681172 -0.867659
# cycle      -0.852162  1.000000  0.902033    0.832447 -0.699938  0.782496
# disp       -0.847551  0.902033  1.000000    0.790949 -0.710214  0.887980
# horsepower -0.776168  0.832447  0.790949    1.000000 -0.448759  0.658748
# drat        0.681172 -0.699938 -0.710214   -0.448759  1.000000 -0.712441
# wt         -0.867659  0.782496  0.887980    0.658748 -0.712441  1.000000
# qsec        0.418684 -0.591242 -0.433698   -0.708223  0.091205 -0.174716
# am          0.599832 -0.522607 -0.591227   -0.243204  0.712711 -0.692495
# ...
